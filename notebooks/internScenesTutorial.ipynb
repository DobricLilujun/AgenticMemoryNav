# %% [markdown]
# # InternScenes Tutorial
# Welcome to the InternScenes tutorial.
#
# This demo shows the usage of dataset Explorer.

# %% [markdown]
# ## Compose a scene using models from assets library

# %% [markdown]
# > **Note on running this tutorial (fixed)**
# > The code below is correct. It relies on `compose_scenes.py`, whose data/output
# > paths are resolved from the InternScenes package root. Two fixes were applied to
# > the module so the tutorial runs from `notebooks/`:
# > 1. `BASE_DIR` is now `Path(__file__).resolve().parents[2]` (was `os.getcwd().parent`),
# >    so `data/` and `tutorial/` resolve regardless of the working directory.
# > 2. The composed-scene output directory is created before export
# >    (`Path(output_glb_path).parent.mkdir(...)`), and the floor/wall/ceiling are read
# >    from `Layout_info/{scene}/StructureMesh/` (not the output dir).
# > Asset availability: 98/117 objects of `scannet/scene0000_00` are present; the 19
# > `objaverse/` assets are archive-only (part of the 101 GB objaverse archive) and are
# > skipped by the download script -- the compose step logs them and continues.
# > **Cell 7 (GLB->USD) requires the Isaac Sim runtime** (`/home/snt/isaacsim/python.sh`)
# > because `glb2usd.py` launches `SimulationApp()`; it cannot run in the plain Python venv.

# %%
# code of composing glb scenes
import os
import sys
from pathlib import Path
BASE_DIR = Path(os.getcwd()).parent
sys.path.append(str(BASE_DIR))

import os
import sys
from pathlib import Path

# 获取项目根目录（假设 notebook 在 notebooks/ 目录下）
PROJECT_ROOT = Path(os.getcwd()).parent  # 或者直接用绝对路径
INTERN_DIR = PROJECT_ROOT / 'external-lib' / 'InternScenes'

# 把 InternScenes 目录加入 sys.path
for p in (str(INTERN_DIR), str(INTERN_DIR / 'InternScenes')):
    if p not in sys.path:
        sys.path.insert(0, p)

from InternScenes.InternScenes_Real2Sim.compose_scenes import SceneComposer

scene_composer = SceneComposer()
scene_name = "scannet/scene0000_00"
scene_composer.compose_one_scene(
    scene_name, 
    use_texture = True,  # whether to use texture
    add_floor = True,  # whether to add floor into the scene
    add_wall = True,  # whether to add wall into the scene
    add_ceiling = True # whether to add ceiling into the scene
)
# Out:
# process_instance 11 done
# process_instance 1 done
# process_instance 14 done
# process_instance 8 done
# process_instance 12 done
# process_instance 3 done
# process_instance 13 done
# process_instance 2 done
# process_instance 23 done
# process_instance 24 done
# process_instance 26 done
# process_instance 29 done
# process_instance 25 done
# process_instance 28 done
# process_instance 7 done
# process_instance 31 done
# process_instance 39 done
# process_instance 16 done
# process_instance 41 done
# process_instance 43 done
# process_instance 51 done
# process_instance 34 done
# process_instance 30 done
# process_instance 38 done
# process_instance 89 done
# process_instance 105 done
# process_instance 54 done
# process_instance 42 done
# process_instance 107 done
# process_instance 63 done
# process_instance 33 done
# process_instance 0 done
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/2/2d1ab5502d369b889e1121b26cc50cad703dfd6f.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-curtain-14df3ee9a690c4767ba870da32919f67.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-curtain-530881554eb0969aba7b6fbd07419a29.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-cup-44ec4f26426fbcab582b8aa1842580e6.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/f5ea1c211113479d9f642529402288e7.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/e0b3b937380e4e9a80f51dae5c3bb778.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-mirror-f6c117de29bb3ec19d15457cf6d49b55.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse_old/d0fbadd14710419388a40d7505fca6c4.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/8f5bcdc1b8ec47a395402c0284b47d6e.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-plant-0ffd448b79e7cea62c740a3273c1eb94.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-book-c371b111817bf9fc4831492311b7290a.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-book-fda3339cb0fad47b2df1116f918cb5bb.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse_old/77e17b8715ef4a07aeb5c8105a0c9393.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-book-8a9105a21cfbad67d6a1a36cc040ee14.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/197bf3f2cb4d40f28fbbbaf7191ad019.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/d150454f2ce94372a164dc06f7538803.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse_old/ac6c00e9d60e423e8b1de41252004f7f.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/49d0b3d6bd134acb8c4804b972151d29.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse_old/1cbd097b5612456ba78b782a8221144e.glb
# process_instance 115 done
# process_instance 67 done
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/6/6267aeaf1c9312e3d756923ede63c52c074ce307.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-pillow-efe6b54f52079980e13fa19e9b07b92d.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/x/xxxx8a64d36ax736ax4dc9x99f8xa2b68365e94e.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/x/xxxx8a64d36ax736ax4dc9x99f8xa2b68365e94e.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/9/94caa134a7e999d3a8df744064177f2350593df1.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-pillow-4e976ee69cb37bcb35d250575f7fc654.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/b/ba01530d043d906de59d3cebf910365e2d0f3b23.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse_old/7e12160f27c94a2fb121fc14878fc972.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/7eb9549a6db1488e8b558bf6eedec6ae.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/f/fcd3cdb03e553cd619428f7b0029ea46bd6bd977.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-picture-56087eb8130d0e371a50e10616ba126e.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-cup-f955665b023ec5db2036a58ac39329bf.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/037b03a3e0274279be4b93b7c7cedf01.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/9/92b0589a6aeb4104cc9b5dc68ad5673f03d41cdb.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-picture-56087eb8130d0e371a50e10616ba126e.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-cup-2ecb8b8b0df7dcb89b62ff1b8a7b0567.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-book-3c22c63e1486ea917350c146b51e38b3.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/a/a13475d927ae8e04cd3bbfa6e384ee0330d8e6a3.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-basket-70c119f3917e33a6592e853b200507ba.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-picture-56087eb8130d0e371a50e10616ba126e.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-picture-5bbee9cdcef36131287da4067d079398.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-shoe-f2cf349d880229fdba42fcede0ff911e.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-book-6e0e47532a4bddbceb93a55c1d4b3518.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/7/78bd5dbf1d365e2f34c10dc468a5decf3024e79b.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/a/ad87281ca93b236560306a08f0953ba340e85c3c.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-towel-59b00a957828daa51d39ea043d0e751d.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/1e88c90205f244f2af50e42079062006.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-basket-7ed06230ee8cbca3b4ca9ca3bef2de56.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/b6aa6e7f91d545f3bb5d4027a83e2da1.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse_old/181e3f451b1f40a6aa17702a8648760b.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/4d19f0d33802411d83ff9061c033268d.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/4/491b19211376dfda637fbbaec406cd5c7d4e6ae1.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-bottle-07249a8ffce099b71b995ad9b8e15cd1.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/538e1ff6ba0f44fc9ff498b62d89f970.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/06f95c94a25b4ab1883ed3b8929cca9d.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/9ecfaed39d23496d803708155a47a3aa.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-towel-3539dd8d0bbe458f390a03842c98800e.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/af514ae1105f4aa5b0496a79e42a0fee.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-bowl-55b8dc1be14ca07768041de21b89b1b1.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-bowl-55b8dc1be14ca07768041de21b89b1b1.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/commercial-others-picture-5bbee9cdcef36131287da4067d079398.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/hssd-models/objects/0/0235b214f27bbe9539c1b9ca31a6ebd252f92c77.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/a7d2d52882c440c1a8ee0815cd314765.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/objaverse/444a0c2f7ed449be9f127341b4eb2137.glb
# Error processing instance: string is not a file: /home/snt/projects/AgenticMemoryNav/data/asset_library/gr100/home-others-towel-f513f4f1ac9b788c47f92f0130486402.glb
# Error adding floor: string is not a file: /home/snt/projects/AgenticMemoryNav/tutorial/examples/composed_scenes/scannet/scene0000_00/StructureMesh/floor.glb
# Error adding wall: string is not a file: /home/snt/projects/AgenticMemoryNav/tutorial/examples/composed_scenes/scannet/scene0000_00/StructureMesh/wall.glb
# Error adding ceiling: string is not a file: /home/snt/projects/AgenticMemoryNav/tutorial/examples/composed_scenes/scannet/scene0000_00/StructureMesh/ceiling.glb

# %% [markdown]
# ## Visualize
#
# ### Visualize bounding boxes using GLB file
# The bounding boxes in the scene can be exported as a glb file and viewed with 3D software such as Blender.

# %%
# code for saving bounding boxes as glb file
import os
import sys
import json
from pathlib import Path
BASE_DIR = Path(os.getcwd()).parent
sys.path.append(str(BASE_DIR))
from InternScenes.InternScenes_Real2Sim.save_bbox_scene import compose_bboxes_scene

# load bboxes
json_path = os.path.join(BASE_DIR, "data/Layout_info/scannet/scene0000_00/layout.json")
save_path = "./examples/bbox_scenes/bbox_scene.glb"
instance_infos = json.load(open(json_path, "r"))
bboxes = []
for instance_info in instance_infos:
    bboxes.append(instance_info["bbox"])

# save bboxes as glb file
compose_bboxes_scene(
    bboxes,  # bboxes to be saved
    save_path,  # path to save the glb file
    show_scene=False  # whether to show the scene
)
# Out:
# scene saved to ./examples/bbox_scenes/bbox_scene.glb

# %% [markdown]
# ### Blender Visualization
#
# For higher-quality rendering and interacting, we recommend using the Blender to visualize and navigate in the scene.
#
# 1. 🔗 Install Blender  [Download Blender](https://www.blender.org/download/)
#
# 2. Open Blender and import the scene file which has been composed in the previous steps.

# %% [markdown]
# ## Convert GLB to USD
#
# This guide explains how to convert a `.glb` file (binary GLTF format) to `.usd` (Universal Scene Description) format using available tools.

# %%
import os
import sys
import asyncio
from pathlib import Path
BASE_DIR = Path(os.getcwd()).parent
sys.path.append(str(BASE_DIR))
from InternScenes.InternScenes_Real2Sim.glb2usd import convert, set_usd_prim_orientation

glb_path = "./examples/bbox_scenes/bbox_scene.glb"
usd_path = os.path.join(BASE_DIR, "tutorial/examples/bbox_scenes/bbox_scene.usd")
print(os.path.exists(usd_path))
status = asyncio.get_event_loop().run_until_complete(
    convert(glb_path, usd_path, load_materials = True)
)
if status:
    print(f"Successfully converted: {usd_path}")
    # set z up axis
    set_usd_prim_orientation(usd_path)

# %% [markdown]
# ## List all model names in one scene

# %%
# code starts here
import os
import sys
import json
from pathlib import Path
BASE_DIR = Path(os.getcwd()).parent
sys.path.append(str(BASE_DIR))

# load model_uids
json_path = os.path.join(BASE_DIR, "data/Layout_info/scannet/scene0000_00/layout.json")
instance_infos = json.load(open(json_path, "r"))
for instance_info in instance_infos:
    model_uid = instance_info["model_uid"]
    print(model_uid)
# Out:
# partnet_mobility/103311
# partnet_mobility/103056
# partnet_mobility/34617
# partnet_mobility/47729
# hssd-models/objects/2/2d1ab5502d369b889e1121b26cc50cad703dfd6f
# gr100/home-others-curtain-14df3ee9a690c4767ba870da32919f67
# gr100/home-others-curtain-530881554eb0969aba7b6fbd07419a29
# partnet_mobility/26657
# partnet_mobility/47701
